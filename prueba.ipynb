# %%
# leer archivos data/IPH_robos_2015_2020_tecmty.xlsx, data/IPH_robos_2021_2024_tecmty_fechas_corregidas.xlsx, data/IPH_robos_ene-ago-2025_tecmty.xlsx y data/unidades economicas cuadrantes.xlsx y data/poblacion cuadrantes.xlsx
import pandas as pd

# Cargar los archivos
robos_2015_2020 = pd.read_excel("data/IPH_robos_2015_2020_tecmty.xlsx")
robos_2021_2024 = pd.read_excel("data/IPH_robos_2021_2024_tecmty_fechas_corregidas.xlsx")
robos_ene_ago_2025 = pd.read_excel("data/IPH_robos_ene-ago-2025_tecmty.xlsx")
poblacion_cuadrantes = pd.read_excel("data/poblacion cuadrantes.xlsx")

# %% [markdown]
# # Robos 2015-2020

# %%
robos_2015_2020.head()
# Out:
#      FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  50848SP 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 1    68587 2015-01-01    99      99        ROBO DE VEHICULO        SI
# 2   68842X 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 3   61105X 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 4    77924 2015-01-01    99      99  ROBO A CASA HABITACION        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.622462 -106.099586    Diana         32
# 1  28.702297 -106.110216    Villa         17
# 2  28.685211 -106.027960  Morelos         45
# 3  28.617434 -106.094153   Zapata         68
# 4  28.725298 -106.112998    Colón         13

# %%
# ver si en la columna fecha hay datos nulos
robos_2015_2020['FECHA'].isnull().sum()
# Out:
# np.int64(0)

# %%
# ver que tipos de datos son las columnas
robos_2015_2020.dtypes
# Out:
# FOLIO                object
# FECHA        datetime64[ns]
# HORA                  int64
# MINUTO                int64
# TIPO                 object
# VIOLENCIA            object
# LATITUD             float64
# LONGITUD            float64
# DISTRITO             object
# CUADRANTE             int64
# dtype: object

# %% [markdown]
# # Robos 2021-2024

# %%
robos_2021_2024.head()
# Out:
#      FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  3196367 2024-01-01    99      99  ROBO A CASA HABITACION        NO
# 1  3196186 2024-01-01    99      99        ROBO DE VEHICULO        NO
# 2  3196158 2024-01-01    99      99  ROBO A CASA HABITACION        NO
# 3  3195958 2024-01-01    99      99          ROBO A NEGOCIO        NO
# 4  3195921 2024-01-01    99      99        ROBO DE VEHICULO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  dia
# 0  28.719604 -106.142035    Colón         12  NaN
# 1  28.717739 -106.089196    Colón         15  NaN
# 2  28.646452 -106.057703    Ángel         35  NaN
# 3  28.621036 -106.030771   Zapata         77  NaN
# 4  28.602171 -105.992235  Morelos         57  NaN

# %%
# ver si en la columna fecha hay datos nulos
robos_2021_2024['FECHA'].isnull().sum()
# Out:
# np.int64(0)

# %%
# ver que tipo de datos son las columnas
robos_2021_2024.dtypes
# Out:
# FOLIO                 int64
# FECHA        datetime64[ns]
# HORA                  int64
# MINUTO                int64
# TIPO                 object
# VIOLENCIA            object
# LATITUD             float64
# LONGITUD            float64
# DISTRITO             object
# CUADRANTE             int64
# dia                 float64
# dtype: object

# %%
# ordenar las fechas de forma ascendente
robos_2021_2024 = robos_2021_2024.sort_values(by='FECHA').reset_index(drop=True)
robos_2021_2024.head()
# Out:
#      FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  1278678 2021-02-01     2      29        ROBO DE VEHICULO        NO
# 1  1278991 2021-02-01    13      34  ROBO A CASA HABITACION        NO
# 2  1278949 2021-02-01    12      33          ROBO A NEGOCIO        NO
# 3  1278846 2021-02-01    10      33          ROBO A NEGOCIO        SI
# 4  1278655 2021-02-01     1      38        ROBO DE VEHICULO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  dia
# 0  28.619408 -106.050057   Zapata         77  NaN
# 1  28.693545 -106.133809    Diana         28  NaN
# 2  28.717592 -106.145238    Colón         12  NaN
# 3  28.677986 -106.128340    Villa         19  NaN
# 4  28.657951 -106.122712    Diana         29  NaN

# %%
# eliminar la columna día
robos_2021_2024 = robos_2021_2024.drop(columns=['dia'])
robos_2021_2024.head()
# Out:
#      FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  1278678 2021-02-01     2      29        ROBO DE VEHICULO        NO
# 1  1278991 2021-02-01    13      34  ROBO A CASA HABITACION        NO
# 2  1278949 2021-02-01    12      33          ROBO A NEGOCIO        NO
# 3  1278846 2021-02-01    10      33          ROBO A NEGOCIO        SI
# 4  1278655 2021-02-01     1      38        ROBO DE VEHICULO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.619408 -106.050057   Zapata         77
# 1  28.693545 -106.133809    Diana         28
# 2  28.717592 -106.145238    Colón         12
# 3  28.677986 -106.128340    Villa         19
# 4  28.657951 -106.122712    Diana         29

# %% [markdown]
# # Robos 2025

# %%
robos_ene_ago_2025.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO       SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO       SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO       NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION       NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO       NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.600113 -106.061258   Zapata         76
# 1  28.609652 -106.065990   Zapata         75
# 2  28.639322 -106.039862  Morelos         51
# 3  28.643275 -106.030795  Morelos         51
# 4  28.693501 -106.115590    Villa         17

# %%
# cambiar nombre de columna VOLENCIA a VIOLENCIA
robos_ene_ago_2025 = robos_ene_ago_2025.rename(columns={'VOLENCIA': 'VIOLENCIA'})
robos_ene_ago_2025.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.600113 -106.061258   Zapata         76
# 1  28.609652 -106.065990   Zapata         75
# 2  28.639322 -106.039862  Morelos         51
# 3  28.643275 -106.030795  Morelos         51
# 4  28.693501 -106.115590    Villa         17

# %%
# ver si hay valores nulos en la columna FECHA
robos_ene_ago_2025['FECHA'].isnull().sum()
# Out:
# np.int64(0)

# %%
# ver que tipos de datos son las columnas
robos_ene_ago_2025.dtypes
# Out:
# FOLIO                 int64
# FECHA        datetime64[ns]
# HORA                  int64
# MINUTO                int64
# TIPO                 object
# VIOLENCIA            object
# LATITUD             float64
# LONGITUD            float64
# DISTRITO             object
# CUADRANTE             int64
# dtype: object

# %% [markdown]
# # dataframes unidos

# %%
# unir los tres dataframes de robos en uno solo, primero robos_2015_2020, luego robos_2021_2024 y al final robos_ene_ago_2025
robos_tot = pd.concat([robos_2015_2020, robos_2021_2024, robos_ene_ago_2025]).reset_index(drop=True)
robos_tot.tail()
# Out:
#          FOLIO      FECHA  HORA  MINUTO              TIPO VIOLENCIA  \
# 35106  1345602 2025-08-30    18      40    ROBO A NEGOCIO        SI
# 35107  1345968 2025-08-30    21       0    ROBO A NEGOCIO        NO
# 35108  1346807 2025-08-31     1      58  ROBO DE VEHICULO        NO
# 35109  1347625 2025-08-31    10       1  ROBO DE VEHICULO        NO
# 35110  1348453 2025-08-31    17      51    ROBO A NEGOCIO        NO
#
#          LATITUD    LONGITUD DISTRITO  CUADRANTE
# 35106  28.615299 -106.097890   Zapata         68
# 35107  28.623672 -106.115850    Diana         32
# 35108  28.649612 -106.001734  Morelos         52
# 35109  28.607209 -106.083870   Zapata         74
# 35110  28.641761 -106.001923  Morelos         52

# %%
robos_tot.shape
# Out:
# (35111, 10)

# %%
# ver cuantos cuadrantes unicos hay en el dataframe robos_tot
robos_tot['CUADRANTE'].nunique()
# Out:
# 77

# %%
# crear columna DIA a partir de la columna FECHA
robos_tot['DIA'] = robos_tot['FECHA'].dt.day
robos_tot.head()
# Out:
#      FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  50848SP 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 1    68587 2015-01-01    99      99        ROBO DE VEHICULO        SI
# 2   68842X 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 3   61105X 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 4    77924 2015-01-01    99      99  ROBO A CASA HABITACION        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  DIA
# 0  28.622462 -106.099586    Diana         32    1
# 1  28.702297 -106.110216    Villa         17    1
# 2  28.685211 -106.027960  Morelos         45    1
# 3  28.617434 -106.094153   Zapata         68    1
# 4  28.725298 -106.112998    Colón         13    1

# %%
# crear columnas de MES
robos_tot['MES'] = robos_tot['FECHA'].dt.month

# crear columna de estacion de acuerdo al mes y al día, teniendo en cuenta que las estaciones empiezan en los siguientes días:
# Primavera: 21 de marzo y termina el 20 de junio
# Verano: 21 de junio y termina el 22 de septiembre
# Otoño: 23 de septiembre y termina el 20 de diciembre
# Invierno: 21 de diciembre y termina el 20 de marzo
def obtener_estacion(mes, dia):
    if mes == 3 and dia >= 21 or mes in [4, 5] or mes == 6 and dia <= 20:
        return 'Primavera'
    elif mes == 6 and dia >= 21 or mes in [7, 8] or mes == 9 and dia <= 22:
        return 'Verano'
    elif mes == 9 and dia >= 23 or mes in [10, 11] or mes == 12 and dia <= 20:
        return 'Otoño'
    else:
        return 'Invierno'
robos_tot['ESTACION'] = robos_tot.apply(lambda x: obtener_estacion(x['MES'], x['DIA']), axis=1)
robos_tot.head()
# Out:
#      FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  50848SP 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 1    68587 2015-01-01    99      99        ROBO DE VEHICULO        SI
# 2   68842X 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 3   61105X 2015-01-01    99      99  ROBO A CASA HABITACION        NO
# 4    77924 2015-01-01    99      99  ROBO A CASA HABITACION        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  DIA  MES  ESTACION
# 0  28.622462 -106.099586    Diana         32    1    1  Invierno
# 1  28.702297 -106.110216    Villa         17    1    1  Invierno
# 2  28.685211 -106.027960  Morelos         45    1    1  Invierno
# 3  28.617434 -106.094153   Zapata         68    1    1  Invierno
# 4  28.725298 -106.112998    Colón         13    1    1  Invierno

# %%
robos_tot[robos_tot['FECHA'] == '2016-03-20']
# Out:
#        FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 4850   81499 2016-03-20    99      99        ROBO DE VEHICULO        SI
# 4851  119917 2016-03-20    99      99          ROBO A NEGOCIO        SI
# 4852  116993 2016-03-20    99      99  ROBO A CASA HABITACION        NO
# 4853   65078 2016-03-20    99      99  ROBO A CASA HABITACION        NO
# 4854  102557 2016-03-20    99      99  ROBO A CASA HABITACION        NO
# 4855   80869 2016-03-20    99      99  ROBO A CASA HABITACION        NO
# 4856   58064 2016-03-20    99      99          ROBO A NEGOCIO        NO
# 4857  120514 2016-03-20    99      99  ROBO A CASA HABITACION        NO
#
#         LATITUD    LONGITUD DISTRITO  CUADRANTE  DIA  MES  ESTACION
# 4850  28.699494 -106.126114    Villa         16   20    3  Invierno
# 4851  28.660428 -106.086792    Villa         25   20    3  Invierno
# 4852  28.663078 -105.978380  Morelos         47   20    3  Invierno
# 4853  28.598716 -106.013873  Morelos         56   20    3  Invierno
# 4854  28.752186 -106.130140    Colón          8   20    3  Invierno
# 4855  28.773529 -106.166469    Colón          3   20    3  Invierno
# 4856  28.640231 -106.080823    Ángel         37   20    3  Invierno
# 4857  28.694495 -106.099549    Villa         20   20    3  Invierno

# %%
# exportar robos_tot a un archivo excel llamado robos_tot_fin.xlsx
robos_tot.to_excel('robos_tot_fin.xlsx', index=False)

# %% [markdown]
# # Crear tabla de cuadrantes

# %%
# crear tabla de 78 cuadrantes, cada fila que sea 1 cuadrante, desde el 1 hasta el 78
cuadrantes_df = pd.DataFrame({'CUADRANTE': range(1, 79)})
cuadrantes_df.head()
# Out:
#    CUADRANTE
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
# ver cuantos cuadrantes hay en el dataframe cuadrantes_df
cuadrantes_df['CUADRANTE'].nunique()
# Out:
# 78

# %% [markdown]
# ## introducir df de poblacion por cuadrante

# %%
poblacion_cuadrantes.head(10)
# Out:
#    cuadrante  poblacion
# 0          3      18838
# 1          4      20919
# 2          5        391
# 3          6      24485
# 4          7      31984
# 5          8      28901
# 6          9      25765
# 7         11      22683
# 8         12      13257
# 9         13      19409

# %%
# ver cuantos cuadrantes unicos hay en el dataframe poblacion_cuadrantes
poblacion_cuadrantes['cuadrante'].nunique()
# Out:
# 75

# %%
# cambiar el nombre de la columna 'cuadrante' a 'CUADRANTE' para hacer merge despues, y también de la columna 'poblacion' a 'POBLACION'
poblacion_cuadrantes = poblacion_cuadrantes.rename(columns={'cuadrante': 'CUADRANTE', 'poblacion': 'POBLACION'})
poblacion_cuadrantes.head()
# Out:
#    CUADRANTE  POBLACION
# 0          3      18838
# 1          4      20919
# 2          5        391
# 3          6      24485
# 4          7      31984

# %%
# unir cuadrantes_df con poblacion_cuadrantes por la columna CUADRANTE
cuadrantes_df = pd.merge(cuadrantes_df, poblacion_cuadrantes, on='CUADRANTE', how='left')
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION
# 0          1        NaN
# 1          2        NaN
# 2          3    18838.0
# 3          4    20919.0
# 4          5      391.0

# %%
# en la columna POBLACION, llenar los valores nulos con 0, y quitar los decimales convirtiendo a entero
cuadrantes_df['POBLACION'] = cuadrantes_df['POBLACION'].fillna(0).astype(int)
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION
# 0          1          0
# 1          2          0
# 2          3      18838
# 3          4      20919
# 4          5        391

# %%
# exportar robos_tot a un archivo excel llamado robos_tot.xlsx
# robos_tot.to_excel('robos_tot.xlsx', index=False)

# %%
# crear columna total de robos, donde sea la suma de robos cuando el cuadrante sea igual al cuadrante de robos_tot
cuadrantes_df['TOTAL DE ROBOS'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[robos_tot['CUADRANTE'] == x].shape[0])
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS
# 0          1          0             136
# 1          2          0               3
# 2          3      18838             715
# 3          4      20919             362
# 4          5        391               8

# %%
# crear columna total de robos con violencia, donde sea la suma de robos con violencia cuando el cuadrante sea igual al cuadrante de robos_tot y la columna VIOLENCIA sea igual a 'SI'
cuadrantes_df['ROBOS CON VIOLENCIA'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2

# %%
# crear columna total de robos sin violencia, donde sea la suma de robos sin violencia cuando el cuadrante sea igual al cuadrante de robos_tot y la columna VIOLENCIA sea igual a 'NO'
cuadrantes_df['ROBOS SIN VIOLENCIA'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA
# 0                  122
# 1                    3
# 2                  618
# 3                  316
# 4                    6

# %%
# crear columna Robos a negocios, donde sea la suma de robos a negocios cuando el cuadrante sea igual al cuadrante de robos_tot y la columna TIPO sea igual a 'ROBO A NEGOCIO'
cuadrantes_df['ROBOS A NEGOCIOS'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])

# crear columna robos a negocios con violencia, donde sea la suma de robos a negocios con violencia cuando el cuadrante sea igual al cuadrante de robos_tot, la columna TIPO sea igual a 'ROBO A NEGOCIO' y la columna VIOLENCIA sea igual a 'SI'
cuadrantes_df['ROBOS A NEGOCIOS CON VIOLENCIA'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

# crear columna robos a negocios sin violencia, donde sea la suma de robos a negocios sin violencia cuando el cuadrante sea igual al cuadrante de robos_tot, la columna TIPO sea igual a 'ROBO A NEGOCIO' y la columna VIOLENCIA sea igual a 'NO'
cuadrantes_df['ROBOS A NEGOCIOS SIN VIOLENCIA'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA  ROBOS A NEGOCIOS  ROBOS A NEGOCIOS CON VIOLENCIA  \
# 0                  122                24                               8
# 1                    3                 0                               0
# 2                  618               148                              71
# 3                  316                56                              30
# 4                    6                 1                               1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA
# 0                              16
# 1                               0
# 2                              77
# 3                              26
# 4                               0

# %%
# crear columna Robos a casa habitacion, donde sea la suma de robos A CASA HABITACION cuando el cuadrante sea igual al cuadrante de robos_tot y la columna TIPO sea igual a 'ROBO A CASA HABITACION'
cuadrantes_df['ROBOS A CASA HABITACION'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])

# crear columna robos a casa habitacion con violencia, donde sea la suma de robos a casa habitacion con violencia cuando el cuadrante sea igual al cuadrante de robos_tot, la columna TIPO sea igual a 'ROBO A CASA HABITACION' y la columna VIOLENCIA sea igual a 'SI'
cuadrantes_df['ROBOS A CASA HABITACION CON VIOLENCIA'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

# crear columna robos a casa habitacion sin violencia, donde sea la suma de robos a casa habitacion sin violencia cuando el cuadrante sea igual al cuadrante de robos_tot, la columna TIPO sea igual a 'ROBO A CASA HABITACION' y la columna VIOLENCIA sea igual a 'NO'
cuadrantes_df['ROBOS A CASA HABITACION SIN VIOLENCIA'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA  ROBOS A NEGOCIOS  ROBOS A NEGOCIOS CON VIOLENCIA  \
# 0                  122                24                               8
# 1                    3                 0                               0
# 2                  618               148                              71
# 3                  316                56                              30
# 4                    6                 1                               1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA  ROBOS A CASA HABITACION  \
# 0                              16                      104
# 1                               0                        2
# 2                              77                      502
# 3                              26                      250
# 4                               0                        6
#
#    ROBOS A CASA HABITACION CON VIOLENCIA  \
# 0                                      3
# 1                                      0
# 2                                      4
# 3                                      7
# 4                                      0
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA
# 0                                    101
# 1                                      2
# 2                                    498
# 3                                    243
# 4                                      6

# %%
# crear columna Robos DE VEHICULOS, donde sea la suma de robos DE VEHICULOS cuando el cuadrante sea igual al cuadrante de robos_tot y la columna TIPO sea igual a 'ROBO DE VEHICULO'
cuadrantes_df['ROBOS DE VEHICULOS'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])

# crear columna robos de vehiculos con violencia, donde sea la suma de robos de vehiculos con violencia cuando el cuadrante sea igual al cuadrante de robos_tot, la columna TIPO sea igual a 'ROBO DE VEHICULO' y la columna VIOLENCIA sea igual a 'SI'
cuadrantes_df['ROBOS DE VEHICULOS CON VIOLENCIA'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

# crear columna robos de vehiculos sin violencia, donde sea la suma de robos de vehiculos sin violencia cuando el cuadrante sea igual al cuadrante de robos_tot, la columna TIPO sea igual a 'ROBO DE VEHICULO' y la columna VIOLENCIA sea igual a 'NO'
cuadrantes_df['ROBOS DE VEHICULOS SIN VIOLENCIA'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA  ROBOS A NEGOCIOS  ROBOS A NEGOCIOS CON VIOLENCIA  \
# 0                  122                24                               8
# 1                    3                 0                               0
# 2                  618               148                              71
# 3                  316                56                              30
# 4                    6                 1                               1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA  ROBOS A CASA HABITACION  \
# 0                              16                      104
# 1                               0                        2
# 2                              77                      502
# 3                              26                      250
# 4                               0                        6
#
#    ROBOS A CASA HABITACION CON VIOLENCIA  \
# 0                                      3
# 1                                      0
# 2                                      4
# 3                                      7
# 4                                      0
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA  ROBOS DE VEHICULOS  \
# 0                                    101                   8
# 1                                      2                   1
# 2                                    498                  65
# 3                                    243                  56
# 4                                      6                   1
#
#    ROBOS DE VEHICULOS CON VIOLENCIA  ROBOS DE VEHICULOS SIN VIOLENCIA
# 0                                 3                                 5
# 1                                 0                                 1
# 2                                22                                43
# 3                                 9                                47
# 4                                 1                                 0

# %%
# crear columnas de total de robos, total de robos con y sin violencia, robos a negocios, robos a negocios con y sin violencia, robos a a casa habitacion, robos a casa habitacion con y sin violencia, robos de vehiculos, robos de vehiculos con y sin violencia para todos los meses
for mes in range(1, 13):
    # crear columna total de robos por mes
    cuadrantes_df[f'TOTAL DE ROBOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes)].shape[0])
    
    # crear columna total de robos con violencia por mes
    cuadrantes_df[f'ROBOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
    
    # crear columna total de robos sin violencia por mes
    cuadrantes_df[f'ROBOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
    
    # crear columna robos a negocios por mes
    cuadrantes_df[f'ROBOS A NEGOCIOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])

    # crear columna robos a negocios con violencia por mes
    cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

    # crear columna robos a negocios sin violencia por mes
    cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
    
    # crear columna robos a casa habitacion por mes
    cuadrantes_df[f'ROBOS A CASA HABITACION MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])

    # crear columna robos a casa habitacion con violencia por mes
    cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

    # crear columna robos a casa habitacion sin violencia por mes
    cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
    
    # crear columna robos de vehiculos por mes
    cuadrantes_df[f'ROBOS DE VEHICULOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])

    # crear columna robos de vehiculos con violencia por mes
    cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

    # crear columna robos de vehiculos sin violencia por mes
    cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# Out:
# /tmp/ipykernel_5505/3635817622.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'TOTAL DE ROBOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes)].shape[0])
# /tmp/ipykernel_5505/3635817622.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'TOTAL DE ROBOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes)].shape[0])
# /tmp/ipykernel_5505/3635817622.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'TOTAL DE ROBOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes)].shape[0])
# /tmp/ipykernel_5505/3635817622.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'TOTAL DE ROBOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes)].shape[0])
# /tmp/ipykernel_5505/3635817622.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/3635817622.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA MES {mes}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['MES'] == mes) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])

# %%
cuadrantes_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA  ROBOS A NEGOCIOS  ROBOS A NEGOCIOS CON VIOLENCIA  \
# 0                  122                24                               8
# 1                    3                 0                               0
# 2                  618               148                              71
# 3                  316                56                              30
# 4                    6                 1                               1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA  ROBOS A CASA HABITACION  \
# 0                              16                      104
# 1                               0                        2
# 2                              77                      502
# 3                              26                      250
# 4                               0                        6
#
#    ROBOS A CASA HABITACION CON VIOLENCIA  ...  ROBOS SIN VIOLENCIA MES 12  \
# 0                                      3  ...                           3
# 1                                      0  ...                           0
# 2                                      4  ...                          35
# 3                                      7  ...                          23
# 4                                      0  ...                           0
#
#    ROBOS A NEGOCIOS MES 12  ROBOS A NEGOCIOS CON VIOLENCIA MES 12  \
# 0                        1                                      1
# 1                        0                                      0
# 2                       11                                      3
# 3                        3                                      3
# 4                        1                                      1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA MES 12  ROBOS A CASA HABITACION MES 12  \
# 0                                      0                               2
# 1                                      0                               0
# 2                                      8                              24
# 3                                      0                              19
# 4                                      0                               0
#
#    ROBOS A CASA HABITACION CON VIOLENCIA MES 12  \
# 0                                             0
# 1                                             0
# 2                                             1
# 3                                             0
# 4                                             0
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA MES 12  ROBOS DE VEHICULOS MES 12  \
# 0                                             2                          1
# 1                                             0                          0
# 2                                            23                          5
# 3                                            19                          5
# 4                                             0                          0
#
#    ROBOS DE VEHICULOS CON VIOLENCIA MES 12  \
# 0                                        0
# 1                                        0
# 2                                        1
# 3                                        1
# 4                                        0
#
#    ROBOS DE VEHICULOS SIN VIOLENCIA MES 12
# 0                                        1
# 1                                        0
# 2                                        4
# 3                                        4
# 4                                        0
#
# [5 rows x 158 columns]

# %%
# crear columnas de total de robos, total de robos con y sin violencia, robos a negocios, robos a negocios con y sin violencia, robos a a casa habitacion, robos a casa habitacion con y sin violencia, robos de vehiculos, robos de vehiculos con y sin violencia para todas las estaciones
# ten en cuenta que las estaciones empiezan en los siguientes días: primavera: 21 de marzo, Verano: 21 de junio, Otoño: 23 de septiembre, Invierno: 21 de diciembre
estaciones = ['Primavera', 'Verano', 'Otoño', 'Invierno']
for estacion in estaciones:
    # crear columna total de robos por estacion
    cuadrantes_df[f'TOTAL DE ROBOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion)].shape[0])
    
    # crear columna total de robos con violencia por estacion
    cuadrantes_df[f'ROBOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
    
    # crear columna total de robos sin violencia por estacion
    cuadrantes_df[f'ROBOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
    
    # crear columna robos a negocios por estacion
    cuadrantes_df[f'ROBOS A NEGOCIOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])

    # crear columna robos a negocios con violencia por estacion
    cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

    # crear columna robos a negocios sin violencia por estacion
    cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])

    # crear columna robos a casa habitacion por estacion
    cuadrantes_df[f'ROBOS A CASA HABITACION {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])

    # crear columna robos a casa habitacion con violencia por estacion
    cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

    # crear columna robos a casa habitacion sin violencia por estacion
    cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])

    # crear columna robos de vehiculos por estacion
    cuadrantes_df[f'ROBOS DE VEHICULOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])

    # crear columna robos de vehiculos con violencia por estacion
    cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])

    # crear columna robos de vehiculos sin violencia por estacion
    cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])

cuadrantes_df.head()
# Out:
# /tmp/ipykernel_5505/1041306477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'TOTAL DE ROBOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion)].shape[0])
# /tmp/ipykernel_5505/1041306477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'TOTAL DE ROBOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion)].shape[0])
# /tmp/ipykernel_5505/1041306477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'TOTAL DE ROBOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion)].shape[0])
# /tmp/ipykernel_5505/1041306477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'TOTAL DE ROBOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion)].shape[0])
# /tmp/ipykernel_5505/1041306477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A NEGOCIOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A NEGOCIO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS A CASA HABITACION SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO A CASA HABITACION') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS CON VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'SI')].shape[0])
# /tmp/ipykernel_5505/1041306477.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cuadrantes_df[f'ROBOS DE VEHICULOS SIN VIOLENCIA {estacion.upper()}'] = cuadrantes_df['CUADRANTE'].apply(lambda x: robos_tot[(robos_tot['CUADRANTE'] == x) & (robos_tot['ESTACION'] == estacion) & (robos_tot['TIPO'] == 'ROBO DE VEHICULO') & (robos_tot['VIOLENCIA'] == 'NO')].shape[0])
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA  ROBOS A NEGOCIOS  ROBOS A NEGOCIOS CON VIOLENCIA  \
# 0                  122                24                               8
# 1                    3                 0                               0
# 2                  618               148                              71
# 3                  316                56                              30
# 4                    6                 1                               1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA  ROBOS A CASA HABITACION  \
# 0                              16                      104
# 1                               0                        2
# 2                              77                      502
# 3                              26                      250
# 4                               0                        6
#
#    ROBOS A CASA HABITACION CON VIOLENCIA  ...  ROBOS SIN VIOLENCIA INVIERNO  \
# 0                                      3  ...                            21
# 1                                      0  ...                             2
# 2                                      4  ...                           163
# 3                                      7  ...                            80
# 4                                      0  ...                             3
#
#    ROBOS A NEGOCIOS INVIERNO  ROBOS A NEGOCIOS CON VIOLENCIA INVIERNO  \
# 0                          5                                        1
# 1                          0                                        0
# 2                         39                                       19
# 3                         13                                        8
# 4                          1                                        1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA INVIERNO  ROBOS A CASA HABITACION INVIERNO  \
# 0                                        4                                17
# 1                                        0                                 2
# 2                                       20                               141
# 3                                        5                                68
# 4                                        0                                 3
#
#    ROBOS A CASA HABITACION CON VIOLENCIA INVIERNO  \
# 0                                               0
# 1                                               0
# 2                                               2
# 3                                               2
# 4                                               0
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA INVIERNO  \
# 0                                              17
# 1                                               2
# 2                                             139
# 3                                              66
# 4                                               3
#
#    ROBOS DE VEHICULOS INVIERNO  ROBOS DE VEHICULOS CON VIOLENCIA INVIERNO  \
# 0                            1                                          1
# 1                            0                                          0
# 2                           10                                          6
# 3                           10                                          1
# 4                            1                                          1
#
#    ROBOS DE VEHICULOS SIN VIOLENCIA INVIERNO
# 0                                          0
# 1                                          0
# 2                                          4
# 3                                          9
# 4                                          0
#
# [5 rows x 206 columns]

# %%
# separar cuadrantes_df en tres dataframes: uno que tenga las columnas de total de robos, total de robos con y sin violencia, y que tenga todo los demas solo para el tipo de robo de negocio; uno que tenga las columnas de total de robos, total de robos con y sin violencia, y que tenga todo los demas solo para el tipo de robo a casa habitacion; y uno que tenga las columnas de total de robos, total de robos con y sin violencia, y que tenga todo los demas solo para el tipo de robo de vehiculo
cuadrantes_negocios_df = cuadrantes_df[['CUADRANTE', 'POBLACION', 'TOTAL DE ROBOS', 'ROBOS CON VIOLENCIA', 'ROBOS SIN VIOLENCIA'] + 
                                 [col for col in cuadrantes_df.columns if 'NEGOCIOS' in col]]
cuadrantes_negocios_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA  ROBOS A NEGOCIOS  ROBOS A NEGOCIOS CON VIOLENCIA  \
# 0                  122                24                               8
# 1                    3                 0                               0
# 2                  618               148                              71
# 3                  316                56                              30
# 4                    6                 1                               1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA  ROBOS A NEGOCIOS MES 1  \
# 0                              16                       2
# 1                               0                       0
# 2                              77                      13
# 3                              26                       2
# 4                               0                       0
#
#    ROBOS A NEGOCIOS CON VIOLENCIA MES 1  ...  \
# 0                                     1  ...
# 1                                     0  ...
# 2                                     7  ...
# 3                                     1  ...
# 4                                     0  ...
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA PRIMAVERA  ROBOS A NEGOCIOS VERANO  \
# 0                                         6                        7
# 1                                         0                        0
# 2                                        12                       45
# 3                                         7                       15
# 4                                         0                        0
#
#    ROBOS A NEGOCIOS CON VIOLENCIA VERANO  \
# 0                                      1
# 1                                      0
# 2                                     19
# 3                                      5
# 4                                      0
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA VERANO  ROBOS A NEGOCIOS OTOÑO  \
# 0                                      6                       4
# 1                                      0                       0
# 2                                     26                      38
# 3                                     10                      15
# 4                                      0                       0
#
#    ROBOS A NEGOCIOS CON VIOLENCIA OTOÑO  ROBOS A NEGOCIOS SIN VIOLENCIA OTOÑO  \
# 0                                     4                                     0
# 1                                     0                                     0
# 2                                    19                                    19
# 3                                    11                                     4
# 4                                     0                                     0
#
#    ROBOS A NEGOCIOS INVIERNO  ROBOS A NEGOCIOS CON VIOLENCIA INVIERNO  \
# 0                          5                                        1
# 1                          0                                        0
# 2                         39                                       19
# 3                         13                                        8
# 4                          1                                        1
#
#    ROBOS A NEGOCIOS SIN VIOLENCIA INVIERNO
# 0                                        4
# 1                                        0
# 2                                       20
# 3                                        5
# 4                                        0
#
# [5 rows x 56 columns]

# %%
cuadrantes_casahabitacion_df = cuadrantes_df[['CUADRANTE', 'POBLACION', 'TOTAL DE ROBOS', 'ROBOS CON VIOLENCIA', 'ROBOS SIN VIOLENCIA'] + 
                                         [col for col in cuadrantes_df.columns if 'CASA HABITACION' in col]]
cuadrantes_casahabitacion_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA  ROBOS A CASA HABITACION  \
# 0                  122                      104
# 1                    3                        2
# 2                  618                      502
# 3                  316                      250
# 4                    6                        6
#
#    ROBOS A CASA HABITACION CON VIOLENCIA  \
# 0                                      3
# 1                                      0
# 2                                      4
# 3                                      7
# 4                                      0
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA  ROBOS A CASA HABITACION MES 1  \
# 0                                    101                              7
# 1                                      2                              1
# 2                                    498                             60
# 3                                    243                             15
# 4                                      6                              2
#
#    ROBOS A CASA HABITACION CON VIOLENCIA MES 1  ...  \
# 0                                            0  ...
# 1                                            0  ...
# 2                                            1  ...
# 3                                            0  ...
# 4                                            0  ...
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA PRIMAVERA  \
# 0                                               34
# 1                                                0
# 2                                              140
# 3                                               57
# 4                                                0
#
#    ROBOS A CASA HABITACION VERANO  \
# 0                              35
# 1                               0
# 2                             143
# 3                              65
# 4                               0
#
#    ROBOS A CASA HABITACION CON VIOLENCIA VERANO  \
# 0                                             1
# 1                                             0
# 2                                             1
# 3                                             2
# 4                                             0
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA VERANO  \
# 0                                            34
# 1                                             0
# 2                                           142
# 3                                            63
# 4                                             0
#
#    ROBOS A CASA HABITACION OTOÑO  ROBOS A CASA HABITACION CON VIOLENCIA OTOÑO  \
# 0                             16                                            0
# 1                              0                                            0
# 2                             78                                            1
# 3                             58                                            1
# 4                              3                                            0
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA OTOÑO  \
# 0                                           16
# 1                                            0
# 2                                           77
# 3                                           57
# 4                                            3
#
#    ROBOS A CASA HABITACION INVIERNO  \
# 0                                17
# 1                                 2
# 2                               141
# 3                                68
# 4                                 3
#
#    ROBOS A CASA HABITACION CON VIOLENCIA INVIERNO  \
# 0                                               0
# 1                                               0
# 2                                               2
# 3                                               2
# 4                                               0
#
#    ROBOS A CASA HABITACION SIN VIOLENCIA INVIERNO
# 0                                              17
# 1                                               2
# 2                                             139
# 3                                              66
# 4                                               3
#
# [5 rows x 56 columns]

# %%
cuadrantes_vehiculos_df = cuadrantes_df[['CUADRANTE', 'POBLACION', 'TOTAL DE ROBOS', 'ROBOS CON VIOLENCIA', 'ROBOS SIN VIOLENCIA'] + 
                                   [col for col in cuadrantes_df.columns if 'VEHICULOS' in col]]
cuadrantes_vehiculos_df.head()
# Out:
#    CUADRANTE  POBLACION  TOTAL DE ROBOS  ROBOS CON VIOLENCIA  \
# 0          1          0             136                   14
# 1          2          0               3                    0
# 2          3      18838             715                   97
# 3          4      20919             362                   46
# 4          5        391               8                    2
#
#    ROBOS SIN VIOLENCIA  ROBOS DE VEHICULOS  ROBOS DE VEHICULOS CON VIOLENCIA  \
# 0                  122                   8                                 3
# 1                    3                   1                                 0
# 2                  618                  65                                22
# 3                  316                  56                                 9
# 4                    6                   1                                 1
#
#    ROBOS DE VEHICULOS SIN VIOLENCIA  ROBOS DE VEHICULOS MES 1  \
# 0                                 5                         0
# 1                                 1                         0
# 2                                43                         6
# 3                                47                         7
# 4                                 0                         1
#
#    ROBOS DE VEHICULOS CON VIOLENCIA MES 1  ...  \
# 0                                       0  ...
# 1                                       0  ...
# 2                                       3  ...
# 3                                       0  ...
# 4                                       1  ...
#
#    ROBOS DE VEHICULOS SIN VIOLENCIA PRIMAVERA  ROBOS DE VEHICULOS VERANO  \
# 0                                           1                          3
# 1                                           0                          1
# 2                                           7                         18
# 3                                          12                         21
# 4                                           0                          0
#
#    ROBOS DE VEHICULOS CON VIOLENCIA VERANO  \
# 0                                        0
# 1                                        0
# 2                                        4
# 3                                        3
# 4                                        0
#
#    ROBOS DE VEHICULOS SIN VIOLENCIA VERANO  ROBOS DE VEHICULOS OTOÑO  \
# 0                                        3                         2
# 1                                        1                         0
# 2                                       14                        24
# 3                                       18                        11
# 4                                        0                         0
#
#    ROBOS DE VEHICULOS CON VIOLENCIA OTOÑO  \
# 0                                       1
# 1                                       0
# 2                                       6
# 3                                       3
# 4                                       0
#
#    ROBOS DE VEHICULOS SIN VIOLENCIA OTOÑO  ROBOS DE VEHICULOS INVIERNO  \
# 0                                       1                            1
# 1                                       0                            0
# 2                                      18                           10
# 3                                       8                           10
# 4                                       0                            1
#
#    ROBOS DE VEHICULOS CON VIOLENCIA INVIERNO  \
# 0                                          1
# 1                                          0
# 2                                          6
# 3                                          1
# 4                                          1
#
#    ROBOS DE VEHICULOS SIN VIOLENCIA INVIERNO
# 0                                          0
# 1                                          0
# 2                                          4
# 3                                          9
# 4                                          0
#
# [5 rows x 56 columns]
