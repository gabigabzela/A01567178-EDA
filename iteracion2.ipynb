# %%
# leer archivos 'data/IPH_robos_2021_2024_tecmty.xlsx' y 'data/IPH_robos_ene-ago-2025_tecmty.xlsx'
import pandas as pd

df_2021_2024 = pd.read_excel('data/IPH_robos_2021_2024_tecmty.xlsx')
df_ene_ago_2025 = pd.read_excel('data/IPH_robos_ene-ago-2025_tecmty.xlsx')

# %%
df_2021_2024.head()
# Out:
#      FOLIO                FECHA  HORA  MINUTO                    TIPO  \
# 0  3196367  2024-01-01 00:00:00    99      99  ROBO A CASA HABITACION
# 1  3196186  2024-01-01 00:00:00    99      99        ROBO DE VEHICULO
# 2  3196158  2024-01-01 00:00:00    99      99  ROBO A CASA HABITACION
# 3  3195958  2024-01-01 00:00:00    99      99          ROBO A NEGOCIO
# 4  3195921  2024-01-01 00:00:00    99      99        ROBO DE VEHICULO
#
#   VIOLENCIA    LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0        NO  28.719604 -106.142035    Colón         12
# 1        NO  28.717739 -106.089196    Colón         15
# 2        NO  28.646452 -106.057703    Ángel         35
# 3        NO  28.621036 -106.030771   Zapata         77
# 4        NO  28.602171 -105.992235  Morelos         57

# %%
df_ene_ago_2025.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO       SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO       SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO       NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION       NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO       NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.600113 -106.061258   Zapata         76
# 1  28.609652 -106.065990   Zapata         75
# 2  28.639322 -106.039862  Morelos         51
# 3  28.643275 -106.030795  Morelos         51
# 4  28.693501 -106.115590    Villa         17

# %%
df_2021_2024.dtypes
# Out:
# FOLIO          int64
# FECHA         object
# HORA           int64
# MINUTO         int64
# TIPO          object
# VIOLENCIA     object
# LATITUD      float64
# LONGITUD     float64
# DISTRITO      object
# CUADRANTE      int64
# dtype: object

# %%
# cambiar el tipo de dato de la columna 'Fecha' a datetime, y que los datos "<Null>" se conviertan en NaT
df_2021_2024['FECHA'] = pd.to_datetime(df_2021_2024['FECHA'], format='%d/%m/%Y', errors='coerce')
df_ene_ago_2025['FECHA'] = pd.to_datetime(df_ene_ago_2025['FECHA'], format='%d/%m/%Y', errors='coerce')

# %%
df_2021_2024.head()
# Out:
#      FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  3196367 2024-01-01    99      99  ROBO A CASA HABITACION        NO
# 1  3196186 2024-01-01    99      99        ROBO DE VEHICULO        NO
# 2  3196158 2024-01-01    99      99  ROBO A CASA HABITACION        NO
# 3  3195958 2024-01-01    99      99          ROBO A NEGOCIO        NO
# 4  3195921 2024-01-01    99      99        ROBO DE VEHICULO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.719604 -106.142035    Colón         12
# 1  28.717739 -106.089196    Colón         15
# 2  28.646452 -106.057703    Ángel         35
# 3  28.621036 -106.030771   Zapata         77
# 4  28.602171 -105.992235  Morelos         57

# %%
# cambiar nombre a columna 'VOLENCIA' por 'VIOLENCIA'
df_ene_ago_2025.rename(columns={'VOLENCIA': 'VIOLENCIA'}, inplace=True)
df_ene_ago_2025.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.600113 -106.061258   Zapata         76
# 1  28.609652 -106.065990   Zapata         75
# 2  28.639322 -106.039862  Morelos         51
# 3  28.643275 -106.030795  Morelos         51
# 4  28.693501 -106.115590    Villa         17

# %%
# hacer concat de los dos dataframes, que el df_ene_ago_2025 se agregue al principio del df_2021_2024
df_robos = pd.concat([df_ene_ago_2025, df_2021_2024], ignore_index=True)
df_robos.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.600113 -106.061258   Zapata         76
# 1  28.609652 -106.065990   Zapata         75
# 2  28.639322 -106.039862  Morelos         51
# 3  28.643275 -106.030795  Morelos         51
# 4  28.693501 -106.115590    Villa         17

# %%
# ver estadísticas descriptivas de df_robos, en específico la columna 'FECHA'
df_robos['FECHA'].describe(include='all')
# Out:
# count                            11081
# mean     2023-02-24 07:18:50.908762624
# min                2021-02-01 00:00:00
# 25%                2022-01-27 00:00:00
# 50%                2023-02-09 00:00:00
# 75%                2024-03-10 00:00:00
# max                2025-08-31 00:00:00
# Name: FECHA, dtype: object

# %%
df_robos.shape
# Out:
# (12278, 10)

# %%
# ver renglones donde FECHA es NaT
df_robos[df_robos['FECHA'].isna()]
# Out:
#          FOLIO FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 4543   2756603   NaT     1       2        ROBO DE VEHICULO        NO
# 4544   2756723   NaT     6      50        ROBO DE VEHICULO        NO
# 4545   2756766   NaT     8      45          ROBO A NEGOCIO        NO
# 4546   2756801   NaT    10       7  ROBO A CASA HABITACION        NO
# 4547   2756820   NaT    10      51          ROBO A NEGOCIO        NO
# ...        ...   ...   ...     ...                     ...       ...
# 11981  1652033   NaT    23      53          ROBO A NEGOCIO        NO
# 11982  1651146   NaT     9       7          ROBO A NEGOCIO        NO
# 11983  1651067   NaT     5      41        ROBO DE VEHICULO        NO
# 11984  1651099   NaT     7      44        ROBO DE VEHICULO        NO
# 11985  1651218   NaT    10      23          ROBO A NEGOCIO        NO
#
#          LATITUD    LONGITUD DISTRITO  CUADRANTE
# 4543   28.650632 -106.058686    Ángel         35
# 4544   28.618501 -106.060972   Zapata         75
# 4545   28.642651 -106.073942    Ángel         36
# 4546   28.652415 -106.080928    Villa         25
# 4547   28.618660 -106.066088   Zapata         75
# ...          ...         ...      ...        ...
# 11981  28.729168 -106.113141    Colón         13
# 11982  28.734838 -106.131418    Colón          7
# 11983  28.676933 -106.004125  Morelos         46
# 11984  28.597629 -106.020398  Morelos         55
# 11985  28.705577 -106.120661    Villa         17
#
# [1197 rows x 10 columns]

# %%
# ver si hay duplicados en las columna de FOLIO
print('La cantidad de datos duplicados en la columna FOLIO es:', df_robos['FOLIO'].duplicated().sum())
# Out:
# La cantidad de datos duplicados en la columna FOLIO es: 726

# %%
# Crear columna MES a partir de la columna FECHA
df_robos['MES'] = df_robos['FECHA'].dt.month
df_robos.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  MES
# 0  28.600113 -106.061258   Zapata         76  1.0
# 1  28.609652 -106.065990   Zapata         75  1.0
# 2  28.639322 -106.039862  Morelos         51  1.0
# 3  28.643275 -106.030795  Morelos         51  1.0
# 4  28.693501 -106.115590    Villa         17  1.0

# %%
#creamos columna estación del año, tomando en cuenta los datos nulos
def estacion_del_año(mes):
    if pd.isnull(mes):
        return None
    elif mes in [12, 1, 2]:
        return 'Invierno'
    elif mes in [3, 4, 5]:
        return 'Primavera'
    elif mes in [6, 7, 8]:
        return 'Verano'
    elif mes in [9, 10, 11]:
        return 'Otoño'

df_robos['ESTACION'] = df_robos['FECHA'].dt.month.apply(estacion_del_año)
df_robos.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  MES  ESTACION
# 0  28.600113 -106.061258   Zapata         76  1.0  Invierno
# 1  28.609652 -106.065990   Zapata         75  1.0  Invierno
# 2  28.639322 -106.039862  Morelos         51  1.0  Invierno
# 3  28.643275 -106.030795  Morelos         51  1.0  Invierno
# 4  28.693501 -106.115590    Villa         17  1.0  Invierno

# %%
# ver renglones donde ESTACION es NaN
df_robos[df_robos['ESTACION'].isna()]
# Out:
#          FOLIO FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 4543   2756603   NaT     1       2        ROBO DE VEHICULO        NO
# 4544   2756723   NaT     6      50        ROBO DE VEHICULO        NO
# 4545   2756766   NaT     8      45          ROBO A NEGOCIO        NO
# 4546   2756801   NaT    10       7  ROBO A CASA HABITACION        NO
# 4547   2756820   NaT    10      51          ROBO A NEGOCIO        NO
# ...        ...   ...   ...     ...                     ...       ...
# 11981  1652033   NaT    23      53          ROBO A NEGOCIO        NO
# 11982  1651146   NaT     9       7          ROBO A NEGOCIO        NO
# 11983  1651067   NaT     5      41        ROBO DE VEHICULO        NO
# 11984  1651099   NaT     7      44        ROBO DE VEHICULO        NO
# 11985  1651218   NaT    10      23          ROBO A NEGOCIO        NO
#
#          LATITUD    LONGITUD DISTRITO  CUADRANTE  MES ESTACION
# 4543   28.650632 -106.058686    Ángel         35  NaN     None
# 4544   28.618501 -106.060972   Zapata         75  NaN     None
# 4545   28.642651 -106.073942    Ángel         36  NaN     None
# 4546   28.652415 -106.080928    Villa         25  NaN     None
# 4547   28.618660 -106.066088   Zapata         75  NaN     None
# ...          ...         ...      ...        ...  ...      ...
# 11981  28.729168 -106.113141    Colón         13  NaN     None
# 11982  28.734838 -106.131418    Colón          7  NaN     None
# 11983  28.676933 -106.004125  Morelos         46  NaN     None
# 11984  28.597629 -106.020398  Morelos         55  NaN     None
# 11985  28.705577 -106.120661    Villa         17  NaN     None
#
# [1197 rows x 12 columns]

# %%
# crear columna franja horaria, teniendo en cuenta que hay horas con valor de 99 (nulo)
def franja_horaria(hora):
    if hora == 99:
        return None
    elif 0 <= hora < 6:
        return 'Madrugada'
    elif 6 <= hora < 12:
        return 'Mañana'
    elif 12 <= hora < 18:
        return 'Tarde'
    elif 18 <= hora < 24:
        return 'Noche'
    else:
        return 'Desconocido'

df_robos['FRANJA HORARIA'] = df_robos['HORA'].apply(franja_horaria)
df_robos.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  MES  ESTACION FRANJA HORARIA
# 0  28.600113 -106.061258   Zapata         76  1.0  Invierno      Madrugada
# 1  28.609652 -106.065990   Zapata         75  1.0  Invierno      Madrugada
# 2  28.639322 -106.039862  Morelos         51  1.0  Invierno         Mañana
# 3  28.643275 -106.030795  Morelos         51  1.0  Invierno         Mañana
# 4  28.693501 -106.115590    Villa         17  1.0  Invierno          Tarde

# %%
# crear columna de VIOLENCIA_BIN donde si es con violencia es 1 y sin violencia es 0
df_robos['VIOLENCIA_BIN'] = df_robos['VIOLENCIA'].apply(lambda x: 1 if x == 'SI' else 0)
df_robos.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  MES  ESTACION FRANJA HORARIA  \
# 0  28.600113 -106.061258   Zapata         76  1.0  Invierno      Madrugada
# 1  28.609652 -106.065990   Zapata         75  1.0  Invierno      Madrugada
# 2  28.639322 -106.039862  Morelos         51  1.0  Invierno         Mañana
# 3  28.643275 -106.030795  Morelos         51  1.0  Invierno         Mañana
# 4  28.693501 -106.115590    Villa         17  1.0  Invierno          Tarde
#
#    VIOLENCIA_BIN
# 0              1
# 1              1
# 2              0
# 3              0
# 4              0

# %%
# crear columna ROBO A NEGOCIO donde si el TIPO es 'ROBO A NEGOCIO' es 1 y si no es 0
df_robos['ROBO A NEGOCIO'] = df_robos['TIPO'].apply(lambda x: 1 if x == 'ROBO A NEGOCIO' else 0)
df_robos.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  MES  ESTACION FRANJA HORARIA  \
# 0  28.600113 -106.061258   Zapata         76  1.0  Invierno      Madrugada
# 1  28.609652 -106.065990   Zapata         75  1.0  Invierno      Madrugada
# 2  28.639322 -106.039862  Morelos         51  1.0  Invierno         Mañana
# 3  28.643275 -106.030795  Morelos         51  1.0  Invierno         Mañana
# 4  28.693501 -106.115590    Villa         17  1.0  Invierno          Tarde
#
#    VIOLENCIA_BIN  ROBO A NEGOCIO
# 0              1               1
# 1              1               1
# 2              0               0
# 3              0               0
# 4              0               1

# %%
# crear columna ROBO A CASA HABITACION donde si el TIPO es 'ROBO A CASA HABITACION' es 1 y si no es 0
df_robos['ROBO A CASA HABITACION'] = df_robos['TIPO'].apply(lambda x: 1 if x == 'ROBO A CASA HABITACION' else 0)
df_robos.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  MES  ESTACION FRANJA HORARIA  \
# 0  28.600113 -106.061258   Zapata         76  1.0  Invierno      Madrugada
# 1  28.609652 -106.065990   Zapata         75  1.0  Invierno      Madrugada
# 2  28.639322 -106.039862  Morelos         51  1.0  Invierno         Mañana
# 3  28.643275 -106.030795  Morelos         51  1.0  Invierno         Mañana
# 4  28.693501 -106.115590    Villa         17  1.0  Invierno          Tarde
#
#    VIOLENCIA_BIN  ROBO A NEGOCIO  ROBO A CASA HABITACION
# 0              1               1                       0
# 1              1               1                       0
# 2              0               0                       0
# 3              0               0                       1
# 4              0               1                       0

# %%
# crear columna ROBO DE VEHICULO donde si el TIPO es 'ROBO DE VEHICULO' es 1 y si no es 0
df_robos['ROBO DE VEHICULO'] = df_robos['TIPO'].apply(lambda x: 1 if x == 'ROBO DE VEHICULO' else 0)
df_robos.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VIOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO        SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO        SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO        NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION        NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO        NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE  MES  ESTACION FRANJA HORARIA  \
# 0  28.600113 -106.061258   Zapata         76  1.0  Invierno      Madrugada
# 1  28.609652 -106.065990   Zapata         75  1.0  Invierno      Madrugada
# 2  28.639322 -106.039862  Morelos         51  1.0  Invierno         Mañana
# 3  28.643275 -106.030795  Morelos         51  1.0  Invierno         Mañana
# 4  28.693501 -106.115590    Villa         17  1.0  Invierno          Tarde
#
#    VIOLENCIA_BIN  ROBO A NEGOCIO  ROBO A CASA HABITACION  ROBO DE VEHICULO
# 0              1               1                       0                 0
# 1              1               1                       0                 0
# 2              0               0                       0                 1
# 3              0               0                       1                 0
# 4              0               1                       0                 0

# %%
# GRAFICAR cantidad de ROBO A NEGOCIO por franja horaria y estación del año
df_robos[df_robos['ROBO A NEGOCIO'] == 1].groupby(['FRANJA HORARIA', 'ESTACION']).size().unstack(fill_value=0).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='FRANJA HORARIA'>
